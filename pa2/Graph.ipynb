# %%
plaintext_change = [1, 7, 20, 29, 31, 29, 35, 34, 28, 25, 28, 34, 29, 31, 30, 29, 31]
key_change = [0, 4, 23, 33, 31, 32, 32, 33, 31, 37, 36, 31, 35, 37, 38, 40, 40]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
plt.plot(plaintext_change, 'k', marker='+', label='Plaintext changed')
plt.plot(key_change, 'k', marker='x', label='Key changed')
plt.xlabel('Round Number')
plt.ylabel('Bit changes in Ciphertext')
plt.title('DES Avalanche test')
plt.legend()
plt.savefig('avalanche.png')
